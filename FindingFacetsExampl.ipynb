# %%
import facetsC
from facetsC import*
# Out:
# finish importing

# %%
base_folder="/home/rana/mymodel4/building/"
entity_file=base_folder+"final_ent.txt"#documents name
entityID_file=base_folder+"sorted_ent_wikiID"#documents IDs
feature_file=base_folder+"features2_that_have_Glove50d.txt"# the terms extracted from the corpus that have pre_traind vector
Wj_file=base_folder+"features2_Glove50d.txt"# the pre_traind word embeddings vectors

ent=[]
fea=[]
idf=[]
with open(entity_file,"r") as f:
    for line in f:
        key= line.strip()
        ent.append(key)
with open(feature_file,"r")as f:
    for line in f:
        key=line.strip()
        fea.append(key)



entities=dict(zip(ent,range(len(ent))))
features=dict(zip(fea,range(len(fea))))



#Reading GloVe pre_trained vectors
##############################################################################
##############################################################################


GloveVectors=import2dArray(Wj_file)


#Reading the labels_all matrix
##############################################################################
##############################################################################
#matrix [num of documents X num of terms] 1 if the word occurs in the document 0 otherwise
labels_all=import2dArray(base_folder+"labels_all.txt")



#Reading MDS directions
##############################################################################
##############################################################################

mds1=import2dArray(base_folder+"dissim_mds100_python.txt")
mdsMAIN=np.array(mds1,dtype=np.float32)


#Split MDS and the labels to train and test
##############################################################################
##############################################################################

mds,mdsTest10_P, trainIndices, testIndices = train_test_split(mdsMAIN, range(len(mdsMAIN)), test_size=0.1,random_state=42)

train_labels = labels_all[trainIndices]#train_labels=pmiweights and labels_all= pmiweightsoriginal

test_labels = np.array(labels_all[testIndices])




'''entityID_file=base_folder+"sorted_ent_wikiID"

entID=[]


with open(entityID_file,"r") as f:
    for line in f:
        key= line.strip()
        entID.append(key)
        '''
        
        
        
        
print('STEP3')        

#learn the directions  using finding_directions which will return the following ndarrays
#1-orderd_features (the terms orderd based on kappa score)
#2-orderd_features_directions(the direction for each term)
#3-orderd_features_directions_GLOVE:
#each line is a concatenation between the term's direction and the term's pre-trained word embedding vectors
#4-orderd_features_Kappa(Kappa scores for each direction)
#5-orderd_features_positiveMovies (movies that classified by the linear classifier as positive)
##############################################################################
##############################################################################


termsToDire=fea
entirespacePath = "/home/rana/mymodel2019/buildingtest/all/"# the folder where we will save the entire space files

orderd_features,orderd_features_directions,orderd_features_directions_GLOVE,orderd_features_Kappa\
,orderd_features_positiveMovies,orderd_features_predictions=finding_directions(fea,mds,-1,
                                                                               termsToDire,GloveVectors,
                                                                               train_labels,entirespacePath)

# In[ ]:
# Out:
# successful import /home/rana/mymodel4/building/features2_Glove50d.txt
# successful import /home/rana/mymodel4/building/labels_all.txt
# successful import /home/rana/mymodel4/building/dissim_mds100_python.txt
# STEP3
# --- 7.152557373046875e-07 seconds ---
# finished:  0
# --- 7.152557373046875e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# finished:  1000
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/all/orderd_featuresPositiveReclean
# starting array
# successful write /home/rana/mymodel2019/buildingtest/all/orderd_featuresReclean
# starting array
# successful write /home/rana/mymodel2019/buildingtest/all/orderd_features_directionsReclean
# starting array
# successful write /home/rana/mymodel2019/buildingtest/all/orderd_features_directions_GLOVEReclean
# starting array
# successful write /home/rana/mymodel2019/buildingtest/all/orderd_features_kappaReclean

# %%
# the folder where we will save the facets files
facets_Path = "/home/rana/mymodel2019/buildingtest/5_dim_Adj/"
# the folder where we will save the remainder files
remainder_Path = "/home/rana/mymodel2019/buildingtest/reminder_Adj/"

# %%
facetsm=Facets(ent,fea,orderd_features,mdsMAIN,mds,mdsTest10_P,trainIndices,testIndices,
               train_labels,test_labels,orderd_features_directions,
               orderd_features_directions_GLOVE,GloveVectors,
               orderd_features_Kappa,orderd_features_positiveMovies,
               orderd_features_predictions,10,10,facets_Path,remainder_Path)

# %%
facetsm.decompose_Space()
# Out:
# 100
# 200
# 300
# 400
# ['january', 'year', 'early', 'first', 'april', 'time', 'times', 'june', 'november', 'day', 'end', 'july', 'years', 'february', 'september', 'period', 'december', 'hours', 'late', 'march']
# Fact:  0
# ['january', 'year', 'early', 'first', 'april', 'time', 'times', 'june', 'november', 'day', 'end', 'july', 'years', 'february', 'september', 'period', 'december', 'hours', 'late', 'march']
# rank is 10
# --- 9.5367431640625e-07 seconds ---
# finished:  0
# --- 9.5367431640625e-07 seconds ---
# --- 7.152557373046875e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# finished:  1000
# --- 9.5367431640625e-07 seconds ---
# --- 1.6689300537109375e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_for_facet_0
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_for_facet_0
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_GLOVE_for_facet_0
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_kappa_for_facet_0
# Top 100 features in the facet
# ['register', 'places', 'national', 'bays', 'frame', 'roof', 'built', 'facade', 'maine', 'gabled', 'gable', 'wood', 'windows', 'time', 'vermont', 'university', 'side', 'story', 'sciences', 'campus', 'first', 'family', 'center', 'street', 'universities', 'century', 'academic', 'entrance', 'structure', 'interior', 'city', 'brick', 'office', 'january', 'floor', 'colleges', 'front', 'year', 'ell', 'education', 'early', 'revival', 'students', 'faculties', 'style', 'main', 'years', 'porch', 'wide', 'example', 'school', 'science', 'arena', 'many', 'construction', 'south', 'basketball', 'wife', 'times', 'period', 'space', 'sash', 'rear', 'undergraduate', 'march', 'december', 'november', 'faculty', 'window', 'cornice', 'company', 'end', 'site', 'project', 'facility', 'graduate', 'east', 'june', 'west', 'home', 'history', 'farm', 'research', 'rankings', 'county', 'college', 'student', 'floors', 'granite', 'place', 'such', 'design', 'late', 'foundation', 'york', 'work', 'rural', 'hall', 'buildings', 'april']
# --- 4.76837158203125e-07 seconds ---
# finished:  0
# --- 1.430511474609375e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# finished:  1000
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_for_facet_0
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_for_facet_0
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_GLOVE_for_facet_0
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_kappa_for_facet_0
# 100
# 200
# 300
# 400
# Fact:  1
# ['century', 'history', 'ancient', 'literature', 'scholars', 'culture', 'society', 'stories', 'books', 'heritage', 'cultural', 'subjects']
# rank is 10
# --- 1.1920928955078125e-06 seconds ---
# finished:  0
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.6689300537109375e-06 seconds ---
# finished:  1000
# --- 9.5367431640625e-07 seconds ---
# --- 7.152557373046875e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_for_facet_1
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_for_facet_1
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_GLOVE_for_facet_1
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_kappa_for_facet_1
# Top 100 features in the facet
# ['faculties', 'undergraduate', 'rankings', 'students', 'office', 'colleges', 'floors', 'graduate', 'county', 'education', 'faculty', 'science', 'tehran', 'history', 'humanities', 'research', 'palace', 'campuses', 'college', 'iranian', 'property', 'architect', 'school', 'iran', 'offices', 'design', 'front', 'style', 'porch', 'floor', 'mansion', 'brick', 'revival', 'culture', 'estate', 'home', 'arena', 'downtown', 'institution', 'stories', 'degrees', 'studies', 'company', 'city', 'student', 'exterior', 'farm', 'space', 'district', 'states', 'ancient', 'heritage', 'ii', 'hall', 'cultural', 'united', 'wide', 'residence', 'programs', 'basketball', 'buildings', 'teams', 'library', 'central', 'engineering', 'construction', 'headquarters', 'rear', 'higher', 'departments', 'part', 'schools', 'east', 'museum', 'architects', 'corner', 'block', 'technology', 'computer', 'royal', 'chemistry', 'mathematics', 'king', 'entablature', 'language', 'architecture', 'books', 'william', 'streets', 'square', 'medical', 'barn', 'cornice', 'road', 'society', 'york', 'death', 'ell', 'facility', 'son']
# --- 7.152557373046875e-07 seconds ---
# finished:  0
# --- 1.1920928955078125e-06 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.430511474609375e-06 seconds ---
# finished:  1000
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_for_facet_1
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_for_facet_1
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_GLOVE_for_facet_1
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_kappa_for_facet_1
# 100
# 200
# 300
# 400
# Fact:  2
# ['united', 'states', 'international', 'world', 'top', 'conference', 'england', 'european', 'london', 'country', 'british', 'europe', 'members', 'american', 'britain', 'group', 'member', 'zealand']
# rank is 10
# --- 7.152557373046875e-07 seconds ---
# finished:  0
# --- 9.5367431640625e-07 seconds ---
# --- 1.9073486328125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# finished:  1000
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_for_facet_2
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_for_facet_2
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_GLOVE_for_facet_2
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_kappa_for_facet_2
# Top 100 features in the facet
# ['united', 'states', 'world', 'international', 'home', 'space', 'construction', 'arena', 'brick', 'revival', 'company', 'downtown', 'farm', 'basketball', 'england', 'mansion', 'wife', 'main', 'top', 'ii', 'son', 'estate', 'corner', 'city', 'facility', 'hall', 'wide', 'engineering', 'ell', 'such', 'facilities', 'technology', 'tallest', 'american', 'residence', 'buildings', 'london', 'european', 'grade', 'programs', 'computer', 'pilasters', 'war', 'group', 'example', 'window', 'largest', 'centre', 'project', 'square', 'events', 'medical', 'hotel', 'member', 'hockey', 'site', 'royal', 'country', 'team', 'original', 'greek', 'members', 'more', 'rear', 'daughter', 'athletic', 'conference', 'barn', 'tower', 'town', 'openings', 'granite', 'teams', 'men', 'sir', 'concrete', 'federal', 'level', 'studies', 'ohio', 'john', 'road', 'institution', 'james', 'sports', 'streets', 'former', 'entablature', 'courses', 'william', 'death', 'language', 'acre', 'skyscraper', 'cornice', 'tenants', 'massachusetts', 'village', 'game', 'architects']
# --- 7.152557373046875e-07 seconds ---
# finished:  0
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.6689300537109375e-06 seconds ---
# finished:  1000
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_for_facet_2
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_for_facet_2
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_GLOVE_for_facet_2
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_kappa_for_facet_2
# 100
# 200
# 300
# 400
# Fact:  3
# ['hotel', 'property', 'buildings', 'hotels', 'estate', 'land', 'tenants', 'houses', 'shops', 'homes', 'retail', 'estates', 'apartments', 'tenant', 'residential', 'housing', 'store']
# rank is 10
# --- 7.152557373046875e-07 seconds ---
# finished:  0
# --- 1.1920928955078125e-06 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 1.6689300537109375e-06 seconds ---
# finished:  1000
# --- 9.5367431640625e-07 seconds ---
# --- 1.430511474609375e-06 seconds ---
# --- 1.9073486328125e-06 seconds ---
# --- 1.430511474609375e-06 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_for_facet_3
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_for_facet_3
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_GLOVE_for_facet_3
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_kappa_for_facet_3
# Top 100 features in the facet
# ['houses', 'hotel', 'residence', 'buildings', 'land', 'headquarters', 'streets', 'architects', 'hotels', 'homes', 'west', 'commercial', 'town', 'schools', 'central', 'area', 'site', 'housing', 'william', 'skyscraper', 'higher', 'firm', 'tenants', 'tower', 'concrete', 'plans', 'ground', 'bank', 'rear', 'road', 'residential', 'section', 'rural', 'east', 'square', 'architectural', 'level', 'window', 'district', 'nearby', 'general', 'death', 'north', 'station', 'centers', 'cottage', 'tenant', 'south', 'centre', 'owner', 'thomas', 'river', 'james', 'facilities', 'retail', 'exterior', 'bay', 'daughter', 'completion', 'programs', 'plaza', 'stone', 'people', 'samuel', 'basement', 'tallest', 'seating', 'pilasters', 'architecture', 'virginia', 'parlor', 'small', 'openings', 'former', 'massachusetts', 'georgian', 'cost', 'private', 'merchant', 'sash', 'shops', 'game', 'kitchen', 'official', 'court', 'decorative', 'avenue', 'companies', 'developer', 'women', 'george', 'granite', 'families', 'forest', 'grade', 'apartments', 'technology', 'post', 'order', 'victorian']
# --- 4.76837158203125e-07 seconds ---
# finished:  0
# --- 1.6689300537109375e-06 seconds ---
# --- 1.9073486328125e-06 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# finished:  1000
# --- 1.1920928955078125e-06 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_for_facet_3
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_for_facet_3
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_GLOVE_for_facet_3
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_kappa_for_facet_3
# 100
# 200
# 300
# 400
# Fact:  4
# ['city', 'district', 'middle', 'rural', 'north', 'coast', 'east', 'village', 'province', 'areas', 'indian', 'south', 'cities', 'southern', 'nation', 'western']
# rank is 10
# --- 9.5367431640625e-07 seconds ---
# finished:  0
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# finished:  1000
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_for_facet_4
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_for_facet_4
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_GLOVE_for_facet_4
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_kappa_for_facet_4
# Top 100 features in the facet
# ['east', 'north', 'south', 'village', 'district', 'areas', 'block', 'project', 'rural', 'middle', 'teams', 'square', 'important', 'york', 'colonial', 'original', 'route', 'season', 'death', 'events', 'board', 'more', 'farmhouse', 'adjacent', 'southern', 'coast', 'john', 'levels', 'western', 'cost', 'council', 'post', 'order', 'stone', 'concerts', 'kitchen', 'most', 'plaza', 'sash', 'october', 'children', 'government', 'general', 'seating', 'entrances', 'cities', 'owners', 'indoor', 'additional', 'association', 'small', 'courthouse', 'use', 'treasury', 'junction', 'development', 'former', 'game', 'window', 'avenue', 'army', 'women', 'employees', 'number', 'manhattan', 'completion', 'games', 'opening', 'level', 'renaissance', 'sports', 'province', 'openings', 'companies', 'architectural', 'museum', 'indian', 'high', 'upper', 'ownership', 'limestone', 'daughter', 'honor', 'cornice', 'museums', 'collection', 'large', 'acre', 'grade', 'section', 'hampshire', 'services', 'king', 'competition', 'mary', 'athletic', 'rectangular', 'capacity', 'third', 'mrs']
# --- 4.76837158203125e-07 seconds ---
# finished:  0
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# finished:  1000
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_for_facet_4
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_for_facet_4
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_GLOVE_for_facet_4
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_kappa_for_facet_4
# 100
# 200
# 300
# 400
# Fact:  5
# ['place', 'october', 'completion', 'fifth', 'next', 'previous', 'date', 'august', 'stage', 'complete', 'later', 'from', 'open', 'figures', 'number']
# rank is 10
# --- 1.1920928955078125e-06 seconds ---
# finished:  0
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# finished:  1000
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 7.152557373046875e-07 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_for_facet_5
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_for_facet_5
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_GLOVE_for_facet_5
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_kappa_for_facet_5
# Top 100 features in the facet
# ['museum', 'place', 'completion', 'architectural', 'oldest', 'number', 'august', 'complex', 'october', 'later', 'next', 'avenue', 'line', 'queen', 'art', 'acre', 'base', 'massachusetts', 'use', 'carriage', 'game', 'part', 'large', 'date', 'foreign', 'largest', 'works', 'fifth', 'student', 'daughter', 'last', 'barn', 'thomas', 'grade', 'owner', 'kitchen', 'winter', 'architecture', 'league', 'police', 'georgian', 'classrooms', 'courses', 'george', 'glass', 'manor', 'garden', 'marble', 'institution', 'figures', 'deco', 'library', 'study', 'nrhp', 'services', 'fireplace', 'landmark', 'smith', 'cabin', 'light', 'fort', 'farmstead', 'da', 'courtyard', 'department', 'short', 'battle', 'former', 'manhattan', 'arts', 'plaza', 'theatre', 'steel', 'river', 'post', 'technology', 'lake', 'prominent', 'branch', 'tallest', 'ice', 'settlement', 'studies', 'system', 'angeles', 'anne', 'merchant', 'visible', 'auditorium', 'heavy', 'from', 'henry', 'courthouse', 'old', 'chapter', 'trade', 'warehouse', 'albert', 'white', 'shingles']
# --- 2.384185791015625e-07 seconds ---
# finished:  0
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# finished:  1000
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 7.152557373046875e-07 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_for_facet_5
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_for_facet_5
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_GLOVE_for_facet_5
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_kappa_for_facet_5
# 100
# 200
# 300
# 400
# Fact:  6
# ['style', 'music', 'classical', 'contemporary', 'typical', 'beautiful', 'features', 'lot', 'styles', 'character', 'tradition', 'fine', 'musical', 'best', 'kind', 'distinctive']
# rank is 10
# --- 9.5367431640625e-07 seconds ---
# finished:  0
# --- 7.152557373046875e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 7.152557373046875e-07 seconds ---
# finished:  1000
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_for_facet_6
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_for_facet_6
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_GLOVE_for_facet_6
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_kappa_for_facet_6
# Top 100 features in the facet
# ['people', 'public', 'team', 'park', 'hockey', 'business', 'styles', 'typical', 'institution', 'women', 'lot', 'george', 'days', 'garden', 'valley', 'capacity', 'example', 'games', 'order', 'robert', 'parlor', 'classical', 'entire', 'music', 'concerts', 'door', 'men', 'features', 'competition', 'contemporary', 'jersey', 'deep', 'grand', 'charles', 'technology', 'athletic', 'system', 'theatre', 'annual', 'venue', 'openings', 'ice', 'distinctive', 'deco', 'owner', 'club', 'courts', 'lisbon', 'services', 'grade', 'post', 'musical', 'storage', 'stone', 'castle', 'community', 'africa', 'seat', 'victorian', 'character', 'chimney', 'homestead', 'upper', 'canada', 'edward', 'cottage', 'pilasters', 'security', 'short', 'steel', 'junior', 'majority', 'federal', 'columns', 'architecture', 'additional', 'access', 'villa', 'population', 'native', 'government', 'gardens', 'english', 'industrial', 'auditorium', 'barn', 'intersection', 'smith', 'monastery', 'arched', 'merchant', 'apartment', 'festival', 'venues', 'room', 'limestone', 'basement', 'primary', 'historical', 'conservation']
# --- 7.152557373046875e-07 seconds ---
# finished:  0
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 7.152557373046875e-07 seconds ---
# finished:  1000
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_for_facet_6
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_for_facet_6
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_GLOVE_for_facet_6
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_kappa_for_facet_6
# 100
# 200
# 300
# 400
# Fact:  7
# ['facility', 'facilities', 'medical', 'medicine', 'hospitals', 'companies', 'private', 'training', 'workers', 'hospital', 'treatment', 'health', 'heart', 'services', 'local', 'maintenance', 'operations', 'businesses']
# rank is 10
# --- 1.1920928955078125e-06 seconds ---
# finished:  0
# --- 1.1920928955078125e-06 seconds ---
# --- 7.152557373046875e-07 seconds ---
# --- 7.152557373046875e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.6689300537109375e-06 seconds ---
# finished:  1000
# --- 1.1920928955078125e-06 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 1.430511474609375e-06 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_for_facet_7
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_for_facet_7
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_GLOVE_for_facet_7
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_kappa_for_facet_7
# Top 100 features in the facet
# ['state', 'kitchen', 'services', 'companies', 'medical', 'technology', 'stone', 'rights', 'mary', 'children', 'hospital', 'courses', 'library', 'historical', 'facilities', 'former', 'georgian', 'gardens', 'much', 'department', 'high', 'technical', 'parts', 'development', 'medicine', 'programs', 'pennsylvania', 'husband', 'federal', 'wealthy', 'rectangular', 'degree', 'theater', 'dining', 'sqft', 'white', 'population', 'fall', 'official', 'sculptures', 'attic', 'ohio', 'fireplace', 'living', 'municipality', 'military', 'james', 'educational', 'tallest', 'few', 'staircase', 'lincoln', 'age', 'local', 'room', 'massive', 'academy', 'polish', 'film', 'king', 'cornice', 'atlanta', 'entablature', 'present', 'northern', 'window', 'training', 'honor', 'multiple', 'variety', 'seating', 'wooden', 'schoolhouse', 'nrhp', 'furnishings', 'muslim', 'trade', 'thomas', 'deco', 'earlier', 'departments', 'institute', 'seats', 'tudor', 'ice', 'monument', 'sons', 'italian', 'barn', 'halls', 'wright', 'investment', 'degrees', 'light', 'restoration', 'event', 'henry', 'mathematics', 'money', 'dr']
# --- 4.76837158203125e-07 seconds ---
# finished:  0
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 7.152557373046875e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# finished:  1000
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_for_facet_7
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_for_facet_7
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_GLOVE_for_facet_7
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_kappa_for_facet_7
# 100
# 200
# 300
# 400
# Fact:  8
# ['fort', 'angeles', 'los', 'virginia', 'michigan', 'kentucky', 'maryland', 'texas', 'nebraska', 'ottawa', 'burlington', 'chicago', 'francisco', 'pittsburgh', 'rhode', 'atlanta', 'florida', 'carolina', 'miami', 'kansas']
# rank is 10
# --- 9.5367431640625e-07 seconds ---
# finished:  0
# --- 7.152557373046875e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 7.152557373046875e-07 seconds ---
# finished:  1000
# --- 7.152557373046875e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_for_facet_8
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_for_facet_8
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_GLOVE_for_facet_8
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_kappa_for_facet_8
# Top 100 features in the facet
# ['major', 'fort', 'virginia', 'banks', 'additional', 'only', 'service', 'los', 'california', 'government', 'court', 'long', 'feet', 'room', 'investment', 'form', 'thomas', 'australia', 'civil', 'eastern', 'post', 'castle', 'centre', 'buenos', 'terrace', 'collection', 'station', 'argentina', 'da', 'deco', 'great', 'greek', 'angeles', 'victorian', 'halls', 'venue', 'planning', 'tall', 'walls', 'mayor', 'municipal', 'aires', 'collections', 'dining', 'barn', 'charles', 'michigan', 'problems', 'particular', 'museums', 'trees', 'argentine', 'shape', 'grant', 'cellar', 'river', 'arches', 'battle', 'community', 'resort', 'neighborhood', 'royal', 'de', 'williams', 'guest', 'institute', 'glass', 'benjamin', 'many', 'railroad', 'juan', 'exchange', 'granite', 'general', 'wilson', 'guide', 'sons', 'kentucky', 'nebraska', 'level', 'chicago', 'exterior', 'douglas', 'native', 'ohio', 'meetings', 'items', 'news', 'pilasters', 'whole', 'safety', 'trustees', 'der', 'outer', 'products', 'carnegie', 'peace', 'alfred', 'free', 'el']
# --- 4.76837158203125e-07 seconds ---
# finished:  0
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 1.9073486328125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# finished:  1000
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 7.152557373046875e-07 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_for_facet_8
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_for_facet_8
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_directions_GLOVE_for_facet_8
# starting array
# successful write /home/rana/mymodel2019/buildingtest/reminder_Adj/orderd_features_kappa_for_facet_8
# 100
# 200
# 300
# 400
# Fact:  9
# ['months', 'may', 'field', 'hands', 'opening', 'following', 'night', 'front', 'week', 'morning', 'minutes', 'wide', 'tour']
# --- 9.5367431640625e-07 seconds ---
# finished:  0
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 9.5367431640625e-07 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# --- 9.5367431640625e-07 seconds ---
# finished:  1000
# --- 1.430511474609375e-06 seconds ---
# --- 1.1920928955078125e-06 seconds ---
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_for_facet_9
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_for_facet_9
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_directions_GLOVE_for_facet_9
# starting array
# successful write /home/rana/mymodel2019/buildingtest/5_dim_Adj/orderd_features_kappa_for_facet_9
# Top 100 features in the facet
# ['press', 'james', 'power', 'old', 'most', 'entry', 'halls', 'crown', 'fireplace', 'level', 'details', 'hill', 'memorial', 'grade', 'prominent', 'foundation', 'exterior', 'merchant', 'manor', 'coliseum', 'artist', 'plan', 'towers', 'italy', 'paintings', 'magazine', 'russian', 'war', 'portion', 'page', 'policy', 'taylor', 'jr', 'steel', 'southwest', 'rectangular', 'chapel', 'nature', 'façade', 'sports', 'presidential', 'metres', 'committee', 'mountain', 'months', 'anne', 'honor', 'same', 'daily', 'damage', 'french', 'guests', 'mother', 'priory', 'artists', 'single', 'religious', 'kingdom', 'ft', 'pilasters', 'purpose', 'cotton', 'motifs', 'congress', 'sir', 'union', 'facades', 'asia', 'evidence', 'nicholas', 'aires', 'significant', 'casa', 'production', 'rancho', 'natural', 'lodge', 'la', 'native', 'seating', 'naval', 'series', 'system', 'owner', 'sites', 'figure', 'columns', 'nineteenth', 'living', 'show', 'el', 'employees', 'guard', 'structural', 'active', 'movie', 'pavilions', 'collections', 'president', 'primary']

# %%
subspaces=np.array(facetsm.facetsSpaces)
print(subspaces.shape)#[numberoFfacets X numberofInstances X dimensionOFFacets]
# Out:
# (10, 3721, 10)
